# %% [markdown]
# <h1 style="text-align: center;">Knowledge Spillovers in Innovation Economics</h1>
# <h3 style="text-align: center;">Understanding University Endowment Changes and Patent Concentration Correlations</h3>
# &nbsp;
# <h4 style="text-align: center;">by Maya Niyogi</h4>
# <h5 style="text-align: center;"><a href="https://github.com/llorracc/as.180.369">AS.180.369</a> Tools for Writing a Research Paper in Economics (Fall 2024)</h4>
# <h6 style="text-align: center;">Johns Hopkins University</h5>
#
# <h5 style="text-align: center;"><strong></strong></h5>
# <h5 style="text-align: center;"></h5>
# &nbsp;
# <h4 style="text-align: center;"></h4> <h4 style="text-align: center;"></h4>
# <h6 style="text-align: center;"><a
# href="https://github.com/dedwar65/RS100_Discussion"></a></h6>

# %% [markdown]
# <h3 style="text-align: center;">Motivation</h3>
#
# - Prior understanding that <strong>academic research and industry research/activity</strong> go hand-in-hand
#
# - <strong>Urban Economics</strong>: agglomeration forces motivate the creation of cities
#     - Consequence of agglomeration forces: <u>knowledge spillovers</u>
#     - Results in innovation economies

# %% [markdown]
# <h3 style="text-align: center;">What are &ldquo;Agglomeration Forces&rdquo;?</h3>
#
# - Agglomeration forces: benefits that firms and individuals gain from being near each other.
#     - Manifest in <strong>reduced transportation costs, shared resources, and enhanced communication</strong>
#     - E.g., Silicon Valley, New York City financial districts
#
# - Key mechanisms:
#     1. <strong>Sharing</strong>: Firms share infrastructure, suppliers, and services, reducing costs.
#     2. <strong>Matching</strong>: Better matching of workers with jobs due to a larger labor pool.
#     3. <strong>Learning</strong>: Increased innovation and productivity through knowledge spillovers and collaboration.

# %% [markdown]
# <h3 style="text-align: center;">A Visualization of Agglomeration Forces</h3>
#
# ![Agg_Economies_Image.png](attachment:cf8aa3cd-278c-4f25-81cd-c24dfad5bed0.png)

# %% [markdown]
# <h3 style="text-align: center;">But What Constitutes a &ldquo;Spillover&rdquo;?</h3>
#
# - Occur when effects (e.g., information or research) created by one firm or individual benefits others without direct compensation
#     - Often happens in clusters of related industries.
#
# - Different types of spillovers:
#     1. <strong>Localized Spillover</strong>:  Knowledge spreads within a geographic area, enhancing local innovation.
#     2. <strong>Technological Spillover</strong>: Innovations in one firm or industry benefit others, leading to overall economic growth.
#     3. <strong>Knowledge Spillover</strong>: Increased innovation and productivity through knowledge exchange and collaboration.

# %% [markdown]
# <h3 style="text-align: center;">Visualizing a Knowledge Spillover</h3>
#
# - <strong>Carlino (2001)</strong>: Knowledge Spillover is <em>"an exchange of ideas among individuals"</em>
#
# ![Knowledge_Spillover_Mechanisms.png](attachment:363e1014-69e3-4381-a515-bf8baa8a225f.png)

# %% [markdown]
# <h3 style="text-align: center;">Importance and Impacts</h3>
#
# - <strong>Economic Growth</strong>: Agglomeration forces and knowledge spillovers drive <u>regional development and innovation</u>, leading to <u>cumulative growth</u> and <u>increased returns on investment</u>.
#
# - <strong>Policy implications</strong>:
#     - <em><u>Education and Training</u></em>: Investing in human capital enhances the benefits from agglomeration.
#     - <em><u>Urban planning</u></em>: Encourages the development of "clusters" through zoning and infrastructure investments.
#
# - But there are <strong>challenges</strong>...
#     - <em><u>Congestion and Costs</u></em>: High density can lead to increased living costs and regional congestion.
#     - <em><u>Inequalities</u></em>: Benefits may not be evenly distributed, leading to regional disparities.

# %% [markdown]
# <h3 style="text-align: center;">Studies on Agglomeration Forces and Importance</h3>
#
# - <strong>Empirical Analysis</strong>: Combes and Gobillon (2015) provided comprehensive analysis of agglomeration economies
#     - Found that local density, industrial specialization, and human capital externalities <u>significantly boost productivity and employment</u>
#
# - <strong>Simultaneous Agglomeration and Spillover Effects</strong>: Springer (2004) developed simultaneous equation model to address the endogeneity in traditional models
#     - Confirmed that <u>agglomeration and knowledge spillovers jointly enhance economic outcomes</u>

# %% [markdown]
# <h3 style="text-align: center;">Studies on Knowledge Spillovers and Importance</h3>
#
# - <strong>Study on Networks of Scientists</strong>: Zacchia (2019) demonstrated that interactions between inventors from different firms significantly enhance innovation and productivity
#     - Study used network of publicly traded companies to show that <u>R&D performed by connected firms leads to higher innovation rates</u>
#
# - <strong>Impacts on Economic Growth</strong>: Review by MDPI (2024) highlighted that knowledge spillovers contribute to economic resilience and growth, especially during recessions
#     - Study analyzed effects in three different countries (Germany, France, Spain), illustrating the <u>positive impact of knowledge diffusion</u>

# %% [markdown]
# <h3 style="text-align: center;">However, There are Few Studies <em>Quantifying</em> Knowledge Spillovers</h3>
#
# - <strong>Bloom (2019)</strong>: Examined effects of Chinese trade on U.S. employment, but <u>does not fully quantify the knowledge spillovers involved</u>
#
# - <strong>Eriksson (2021)</strong>: Explored trade shocks in U.S. manufacturing, with <u>limited focus on the quantification of knowledge spillovers</u>
#
# - <strong>Hausman (2012)</strong>: Investigated role of university innovation in local economic growth, but <u>did not fully measure the extent of knowledge spillovers</u>
#
# - <strong>Abramovsky (2007)</strong>: Analyzed influence of university research on business R&D location, with <u>limited quantification of knowledge spillovers</u>
#
# - <strong>Ellison (2007)</strong>: Provided evidence on industry agglomeration factors, but <u>did not fully quantify knowledge spillovers</u>

# %% [markdown]
# <h2 style="text-align: center;">So, We Wanted to Explore this Information Gap... </h2>

# %% [markdown]
# <h3 style="text-align: center;">The Set-Up</h3>
#
# - Want to understand a spatial relationship between <strong>university research</strong> and <strong>industry innovation</strong>
#     - From past studies, have seen that these variables are difficult to observe and quantify
#
# - Instrumental variables are beneficial as proxies:
#     - <u>University research</u>: University endowment spending serves as instrumental variable as research conducted is a function of university spending.
#     - <u>Industry innovation</u>: Regional number of patents filed serves as instrumental variable as patent filings are a precursor to implementation and commercialization of research.

# %% [markdown]
# <h3 style="text-align: center;">The Data</h3>
#
# - <u>University endowment spending</u>: United States Department of Education's [College Scorecard API](https://collegescorecard.ed.gov/data/api-documentation/) serves statistics about universities nationwide.
#     - University spending was computed using ```(endowment.begin - endowment.end)```
#
# - <u>Patent count</u>: United States Patent and Trademark Office (USPTO) [Patent View API](https://developer.uspto.gov/api-catalog/patentsview) provides patent concentration data.
#
# - Focused on 2021 data, due to API processing constraints and availability.

# %% [markdown]
# <h3 style="text-align: center;">The Models: Spatial Graphs</h3>
#
# - Utilized python's [plotly.express](https://plotly.com/python/plotly-express/) package to create interactive spatial maps of university endowment change concentrations and patent concentrations
#     - Helped develop visual understanding of concentrations and distributions.

# %% [markdown]
# <h3 style="text-align: center;">The Models: Spatial Graphs&mdash;Endowment Change Concentrations</h3>
#
# ![Endowment_Plot.png](attachment:021a3c87-c03f-4b5f-b057-0a806de808d4.png)

# %% [markdown]
# <h3 style="text-align: center;">The Models: Spatial Graphs&mdash;Filed Patent Concentrations</h3>
#
# ![Patent_Concentrations.png](attachment:70b0e083-f9c5-4ead-ae19-8dccf2b887ee.png)

# %% [markdown]
# <h3 style="text-align: center;">The Models: Comparing Visual Trends Between Endowment Changes and Patent Concentrations</h3>
#
# - <u>Endowment level changes</u>:
#     - West Coast (lower California)(Washington), Eastern Midwest, East Coast (upper New York)
#
# - <u>Patent concentrations</u>:
#     - West Coast, Upper Midwest, Upper East Coast have heaviest concentrations
#
# ![Endowment_vs_Patents.png](attachment:aa93e13e-26fc-4128-80a1-bf2b06ea5df5.png)
#
# Output: ```Correlation between Patent Counts and Endowment Change: -0.147741416615222```

# %% [markdown]
# <h3 style="text-align: center;">The Analyses: Understanding Correlations Between Endowment Changes and Patent Concentrations</h3>
#
# ![Regression.png](attachment:e23fda35-a5bf-47a4-8275-ca022fe0b4a1.png)

# %% [markdown]
# ![Regression_w_trendline.png](attachment:e18cec0e-c1a2-44c7-b7d5-c483d2ebaa14.png)
#
# - We see a slight negative relationship, meaning as the change in endowment <strong>increases</strong> (more is spent), the number of patents filed regionally <strong>decreases</strong>
#     - That's interesting; let's take a closer look at the numbers!

# %% [markdown]
# - Important Caveats!
#   1. I have an extremely cursory/low level of familiarity with applied regression analysis before this course.
#   2. The instrumental variables may not be the best proxies; I have yet to take Econometrics.
#   3. My knowledge has only come from Prof. Carroll, Eitan and Adrian, or ChatGPT/Claude.

# %% [markdown]
# <h3 style="text-align: center;">The Analyses: Understanding Correlations Between Endowment Changes and Patent Concentrations</h3>
#
# ![OLS_Results_CORRECTED.png](attachment:52f54d2f-c762-4c78-8b72-831dd0561402.png)

# %% [markdown]
# <h3 style="text-align: center;">Understanding Correlations Between Endowment Changes and Patent Concentrations</h3>

# %% [markdown]
# ### Key Observations:
# 1. **Model**:
#    - Independent variable: `endowment_diff`
#    - Dependent variable: `Counts`

# %% [markdown]
# ### Key Observations:
# 2. **Coefficients**:
#    - Intercept (`const`): 30.7436 (significant, p = 0.00).
#    - Slope (`x1`): -496,500 (significant, p = 0.030).
#      - Suggests that for every additional patent, the endowment difference decreases by approximately 496,500 units (e.g., dollars).

# %% [markdown]
# ### Key Observations:
# 3. **Goodness of Fit**:
#    - R^2 = 0.022: Only 2.2% of the variability in endowment differences is explained by patent counts, indicating a weak relationship.
#        - This is still an improvement over my original results!
#    - Adjusted R^2 = 0.017: Remains low, confirming a weak explanatory power.

# %% [markdown]
# ### Key Observations:
# 4. **Statistical Significance**:
#    - The overall model's p-value (Prob(F-statistic)) is 0.0303, indicating that the model is statistically significant at the 5% level, though the relationship is not strong.

# %% [markdown]
# ### Key Observations:
# 5. **Diagnostics**:
#    - Durbin-Watson: 1.968 suggests no strong autocorrelation in residuals.
#    - Omnibus and Jarque-Bera tests: Indicate non-normality of residuals (could require transformation or additional variables!).

# %% [markdown]
# <h3 style="text-align: center;">We Found Very <strong>Little Correlation</strong> Between <u>University Endowment Spending</u> (University Research) and <u>Patents Filed</u> (Innovation) </h3>
#
# - Weak r$^2$ vaue suggests other factors likely play larger role in explaining patent filing concentrations
#     - Makes sense! Oftentimes research is funded by outside organizations.
#         - Better instrumental variable might've been papers published for university research proxy
#     - Omnibus results imply that a Normality test was not suitable, so may have stronger relationship if using a different test.
#
# - Original question was can these two variables quantify knowledge spillovers
#     - Found a (weak) relationship, so endowment spending and patent concentrations are a decent starting block from which to investigate other potential quantifiers!

# %% [markdown]
# <h1 style="text-align: center;">Thank you!</h1>
# <h4 style="text-align: center;">Please feel free to contact me for further questions or discussion by <a href="mniyogi1@jh.edu">email</a> or on <a href="https://www.linkedin.com/in/mayaniyogi/">LinkedIn</a>!</h3>
